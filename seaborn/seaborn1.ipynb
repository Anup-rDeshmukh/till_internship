# %%
import seaborn as sns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

roll_no=[1,2,3,4,5,6,7,8,9]
marks=[34,5,43,54,25,76,45,23,75]
df=pd.DataFrame({"roll_no":roll_no,"marks":marks})
df
# Out:
#    roll_no  marks
# 0        1     34
# 1        2      5
# 2        3     43
# 3        4     54
# 4        5     25
# 5        6     76
# 6        7     45
# 7        8     23
# 8        9     75

# %%
sns.lineplot(x="roll_no",y="marks",data=df)
plt.title('report')
# Out:
# Text(0.5, 1.0, 'report')

# %%
sns_df=sns.load_dataset('planets')
sns_df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
sns.lineplot(x='orbital_period',y='distance',data=sns_df)
plt.title('planet')
# Out:
# Text(0.5, 1.0, 'planet')

# %%
company_df=pd.read_csv("hr_data.csv")
company_df.head()
# Out:
#    employee_id  number_project  average_montly_hours  time_spend_company  \
# 0         1003               2                   157                   3
# 1         1005               5                   262                   6
# 2         1486               7                   272                   4
# 3         1038               5                   223                   5
# 4         1057               2                   159                   3
#
#    Work_accident  left  promotion_last_5years department  salary
# 0              0     1                      0      sales     low
# 1              0     1                      0      sales  medium
# 2              0     1                      0      sales  medium
# 3              0     1                      0      sales     low
# 4              0     1                      0      sales     low

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x='department',y='left', data=company_df)


plt.title('resignation')
# Out:
# Text(0.5, 1.0, 'resignation')

# %%
sns.lineplot(x='number_project',y='average_montly_hours', data=company_df, hue='department')
# Out:
# <Axes: xlabel='number_project', ylabel='average_montly_hours'>
